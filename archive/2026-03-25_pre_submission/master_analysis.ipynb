# %% [markdown]
# # Master Thesis Analysis: LLM Knowledge Cutoffs and Python Library Diffusion
#
# **Author:** Roland Tuboly
# **Status:** Finalized Empirical Results (March 21, 2026)
#
# ## 1. Research Objective
# This notebook implements the finalized **Suppression Framework** to study the diffusion of Python libraries around the September 2021 LLM training cutoff. We test whether libraries released post-cutoff suffer a "discovery tax" because they are excluded from the model's training data.
#
# ### Core Findings Summary (per Memo #05):
# - **The Suppression Fact:** Successful libraries suffer a **-12.79 log point "Excess Jump"** in adoption relative to historical seasonal norms.
# - **The Barrier to Entry:** Libraries released post-cutoff are **14.5 percentage points (p < 0.0001)** less likely to reach basic success thresholds, creating a significant survival hurdle.
# - **The Activation Mechanism:** This diffusion gap only appeared **after** the release of ChatGPT (Nov 2022), confirming the gap is driven by LLM-mediated discovery.
# - **The Systemic Wall:** Suppression is a broad ecosystem effect; while directionally High AI Exposure libraries suffer less, the difference is not statistically significant ($p = 0.179$).

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import statsmodels.formula.api as smf
from pathlib import Path
import sys
sys.path.append('scripts')
from config import FINAL_DIR, RESULTS_DIR, FIGURES_DIR, DONUT_WEEKS, MAIN_ANALYSIS_DATA
from utils import setup_plotting_style

setup_plotting_style()
plt.rcParams["figure.figsize"] = (10, 6)

# Finalized Parameters (per Memo #05)
BW_MAIN = 13
SUCCESS_THRESHOLD = 500 # "Successful" tier filter

# %% [markdown]
# ## 2. The "Activation" Smoking Gun
# We visualize the adoption trajectories of the July 2021 (Pre-cutoff) vs. October 2021 (Post-cutoff) cohorts. The divergence only "activates" after ChatGPT's release.

# %%
from IPython.display import Image, display
traj_path = FIGURES_DIR / "long_horizon_trajectory_pypi.png"
if traj_path.exists():
    display(Image(filename=str(traj_path)))
    print("Notice the minimal divergence before Nov 2022 and the persistent gap thereafter.")

# %% [markdown]
# ## 3. The Suppression Framework (Diff-in-RDD)
# To isolate the true LLM effect from seasonal noise, we compare the 2021 cohort against historical placebos (2018-2020). The "Excess Jump" represents the unique penalty of the knowledge cutoff.

# %%
supp_path = FIGURES_DIR / "suppression_visual_success_500.png"
if supp_path.exists():
    display(Image(filename=str(supp_path)))

results_path = RESULTS_DIR / "diff_in_rdd_tiers.csv"
if results_path.exists():
    df_res = pd.read_csv(results_path)
    print("\nFinalized Diff-in-RDD Estimates (Seasonal Suppression):")
    display(df_res[["Tier", "Outcome", "Excess_Jump", "P_value", "N"]].round(4))

# %% [markdown]
# ## 4. Mechanism: Systemic Knowledge Wall
# We use a formal interaction model to test if AI exposure moderates the effect. While High AI libraries show directionally smaller suppression, the interaction is not statistically significant, pointing to a systemic ecosystem-wide barrier.

# %%
interact_path = RESULTS_DIR / "mechanism_interaction_results.csv"
if interact_path.exists():
    df_interact = pd.read_csv(interact_path)
    print("Formal Mechanism Moderation Results (Interaction Model):")
    display(df_interact.round(4))

mech_path = FIGURES_DIR / "mechanism_split_total_downloads_52wk.png"
if mech_path.exists():
    display(Image(filename=str(mech_path)))

# %% [markdown]
# ## 5. Persistence and Conclusion
# The empirical evidence supports a robust **Suppression Effect**:
# 1. **Durable Gap:** The diffusion gap identified in late 2022 persists through early 2026 with no evidence of catch-up.
# 2. **The Barrier to Entry:** Post-cutoff libraries suffer a 14.5% drop in survival probability, suggesting LLMs uniquely suppress the emergence of new competition.
# 3. **Causal Logic:** The combination of the Diff-in-RDD suppression and the post-AI activation timing provides strong causal evidence that LLM knowledge cutoffs shape the software ecosystem.
# 4. **Conclusion:** Being excluded from an LLM knowledge set creates a significant "discovery tax" for new tools, narrowing collective variety by steering users toward established, pre-cutoff software.
